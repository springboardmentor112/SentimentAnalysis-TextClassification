# %%
import nltk

# %%
import pandas as pd

# %%
import re

# %%
data_file = pd.read_csv('D:/Sentiment Analysis/reviews.csv')

# %% [markdown]
# **#Lower Case**

# %%
data_file['content']=data_file['content'].apply(lambda x: " ".join(x.lower() for x in str(x).split()))

# %%
print(data_file)
# Out:
#                                    reviewId               userName  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %% [markdown]
# **#Remove Links**

# %%
url_pattern = re.compile(r'https://\S+')

# %%
def remove_urls(text):
    return url_pattern.sub('',text)

# %%
data_file['content']=data_file['content'].apply(remove_urls)

# %%
print(data_file)
# Out:
#                                    reviewId               userName  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %% [markdown]
# **#Remove Next Lines**

# %%
data_file['content']=data_file['content'].replace('\n',' ',regex=True)

# %%
print(data_file)
# Out:
#                                    reviewId               userName  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %% [markdown]
# **#Words Containing Numbers**

# %%
def remove_num(text):
    return re.sub('\S*\d\S*','',text).strip()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\divit\AppData\Local\Temp\ipykernel_11308\2171675631.py:2: SyntaxWarning: invalid escape sequence '\S'
#   return re.sub('\S*\d\S*','',text).strip()

# %%
data_file['content']=data_file['content'].apply(remove_num)

# %%
print(data_file)
# Out:
#                                    reviewId               userName  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %% [markdown]
# **#Extra Spaces**

# %%
def extra_spaces(text):
    return re.sub(' +',' ',text)

# %%
data_file['content']=data_file['content'].apply(extra_spaces)

# %%
print(data_file)
# Out:
#                                    reviewId               userName  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %% [markdown]
# **#Special Characters**

# %%
data_file['content']=data_file['content'].replace(r'[^A-Za-z0-9]+',' ',regex=True)

# %%
print(data_file)
# Out:
#                                    reviewId               userName  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %% [markdown]
# **#Removal of Stop Words**

# %%
from nltk.corpus import stopwords

# %%
stop_words=set(stopwords.words('english'))

# %%
def remove_stop(x):
    return ' '.join([word for word in str(x).split() if word not in stop_words])

# %%
data_file['content']=data_file['content'].apply(lambda x: remove_stop(x))

# %%
print(data_file)
# Out:
#                                    reviewId               userName  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %% [markdown]
# **#Stemming**

# %%
from nltk.stem.porter import PorterStemmer

# %%
stemmer=PorterStemmer()

# %%
def stem_words(text):
    word_tokens=text.split()
    stems= ' '.join([stemmer.stem(word) for word in word_tokens])
    return stems

# %%
data_file['content']=data_file['content'].apply(stem_words)

# %%
print(data_file)
# Out:
#                                    reviewId               userName  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %% [markdown]
# **#Lemmatization**

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer=WordNetLemmatizer()

# %%
def lemmatize_word(text):
    word_tokens =text.split()
    lemmas= ' '.join([lemmatizer.lemmatize(word,pos='v') for word in word_tokens])
    return lemmas

# %%
data_file['content']=data_file['content'].apply(lemmatize_word)

# %%
print(data_file)
# Out:
#                                    reviewId               userName  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %%
from nrclex import NRCLex

# %%
data_file['emotions']=data_file['content'].apply(lambda x: NRCLex(x).affect_frequencies)

# %%
data_file = pd.concat([data_file.drop(['emotions'], axis=1), data_file['emotions'].apply(pd.Series)],axis=1)

# %%
print(data_file)
# Out:
#                                    reviewId               userName  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...
