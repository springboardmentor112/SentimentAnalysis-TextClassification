# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading Data

# %%
df = pd.read_csv("reviews.csv")

# %% [markdown]
# # Showing Data

# %%
df
# Out:
#                                    reviewId               userName  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("reviews.csv")

# Check the column names in the DataFrame
print(df.columns)

# Convert all text in the 'content' column to lowercase
df['content'] = df['content'].str.lower()

# Now the 'content' column contains all text in lowercase
# Out:
# Index(['reviewId', 'userName', 'userImage', 'content', 'thumbsUpCount',
#        'reviewCreatedVersion', 'at', 'replyContent', 'repliedAt', 'appVersion',
#        'sortOrder', 'appId'],
#       dtype='object')

# %%
df
# Out:
#                                    reviewId               userName  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("reviews.csv")

# Convert all text in the 'content' column to lowercase
df['content'] = df['content'].str.lower()

# Now the 'content' column contains all text in lowercase

# %%
df
# Out:
#                                    reviewId               userName  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %%
import pandas as pd
import re

# Read the CSV file into a DataFrame
df = pd.read_csv("reviews.csv")

# Convert all text in the 'content' column to lowercase
df['content'] = df['content'].str.lower()

# Convert non-string values to strings
df['content'] = df['content'].astype(str)

# Remove links from the text in the 'content' column
df['content'] = df['content'].apply(lambda x: re.sub(r'http\S+', '', x))

# Now the 'content' column contains all text with links removed

# %%
df
# Out:
#                                    reviewId               userName  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %%
import pandas as pd
import re

# Read the CSV file into a DataFrame
df = pd.read_csv("reviews.csv")

# Convert all text in the 'content' column to lowercase
df['content'] = df['content'].str.lower()

# Convert non-string values to strings in the 'userImage' column
df['userImage'] = df['userImage'].astype(str)

# Remove links from the text in the 'userImage' column
df['userImage'] = df['userImage'].apply(lambda x: re.sub(r'http\S+', '', x))

# Now the 'userImage' column contains all text with links removed

# %%
df
# Out:
#                                    reviewId               userName userImage  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...       ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                  content  thumbsUpCount  \
# ...

# %%
# Remove newline characters from all columns in the DataFrame
df = df.replace('\n', '', regex=True)

# %%
# Remove newline characters from the 'content' column
df['content'] = df['content'].replace('\n', '', regex=True)

# %%
df
# Out:
#                                    reviewId               userName userImage  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...       ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                  content  thumbsUpCount  \
# ...

# %%
import pandas as pd
import re


# Define a regular expression pattern to match words containing numbers
pattern = r'\b\w*\d\w*\b'

# Remove words containing numbers from the 'content' column
df['content'] = df['content'].replace(pattern, '', regex=True)

# %%
# Out:
#                                    reviewId               userName  \
# 0      0197c118-5c6f-4a7b-894c-970023d1a350                Mar Zur
# 1      94868fb5-a21d-4ef9-ab85-81b2ed3d0785           Devin Rivera
# 2      825da34e-f65d-4ef3-991d-02d5291820d6          Heidi Kinsley
# 3      a49c2875-651a-4c33-b79c-5813780d659e          Daniel Keller
# 4      9482c75e-2e63-46ab-8c94-47273dd6a829          A Google user
# ...                                     ...                    ...
# 16782  e9cebff8-82ad-4191-b196-127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c-3587-4393-a53d-4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d-6e4d-4f0a-9ea6-ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf2-7ca0-4d5e-8cb2-f0f18c813e4d         Keturah Pender
# 16786  8e2deadd-1a6a-4817-89dc-4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %%
import pandas as pd
import re

# Read the CSV file into a DataFrame
df = pd.read_csv("reviews.csv")

# Define a regular expression pattern to match special characters
pattern = r'[^\w\s]'

# Remove special characters from all columns in the DataFrame
df = df.replace(pattern, '', regex=True)

# %%
df
# Out:
#                                reviewId               userName  \
# 0      0197c1185c6f4a7b894c970023d1a350                Mar Zur
# 1      94868fb5a21d4ef9ab8581b2ed3d0785           Devin Rivera
# 2      825da34ef65d4ef3991d02d5291820d6          Heidi Kinsley
# 3      a49c2875651a4c33b79c5813780d659e          Daniel Keller
# 4      9482c75e2e6346ab8c9447273dd6a829          A Google user
# ...                                 ...                    ...
# 16782  e9cebff882ad4191b196127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c35874393a53d4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d6e4d4f0a9ea6ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf27ca04d5e8cb2f0f18c813e4d         Keturah Pender
# 16786  8e2deadd1a6a481789dc4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      httpsplaylhgoogleusercontentcomaACg8ocKoyShmRL...
# 1      httpsplaylhgoogleusercontentcomaALVUjVnKvFNyaR...
# ...

# %%
# Define a regular expression pattern to match links
pattern = r'http\S+'

# %%
df
# Out:
#                                reviewId               userName  \
# 0      0197c1185c6f4a7b894c970023d1a350                Mar Zur
# 1      94868fb5a21d4ef9ab8581b2ed3d0785           Devin Rivera
# 2      825da34ef65d4ef3991d02d5291820d6          Heidi Kinsley
# 3      a49c2875651a4c33b79c5813780d659e          Daniel Keller
# 4      9482c75e2e6346ab8c9447273dd6a829          A Google user
# ...                                 ...                    ...
# 16782  e9cebff882ad4191b196127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c35874393a53d4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d6e4d4f0a9ea6ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf27ca04d5e8cb2f0f18c813e4d         Keturah Pender
# 16786  8e2deadd1a6a481789dc4bd9a198332c    Bhagwan Singh Virik
#
#                                                userImage  \
# 0      httpsplaylhgoogleusercontentcomaACg8ocKoyShmRL...
# 1      httpsplaylhgoogleusercontentcomaALVUjVnKvFNyaR...
# ...

# %%
df['userImage'] = df['userImage'].str.replace(pattern, '', regex=True)

# %%
df
# Out:
#                                reviewId               userName userImage  \
# 0      0197c1185c6f4a7b894c970023d1a350                Mar Zur
# 1      94868fb5a21d4ef9ab8581b2ed3d0785           Devin Rivera
# 2      825da34ef65d4ef3991d02d5291820d6          Heidi Kinsley
# 3      a49c2875651a4c33b79c5813780d659e          Daniel Keller
# 4      9482c75e2e6346ab8c9447273dd6a829          A Google user
# ...                                 ...                    ...       ...
# 16782  e9cebff882ad4191b196127a65e9036d  Alexandra Grafwallner
# 16783  ab74c21c35874393a53d4cb55f3e3c9b          Ljubica Pejic
# 16784  0062b15d6e4d4f0a9ea6ef9b9420d923         Kamiyah Dorsey
# 16785  85318bf27ca04d5e8cb2f0f18c813e4d         Keturah Pender
# 16786  8e2deadd1a6a481789dc4bd9a198332c    Bhagwan Singh Virik
#
#                                                  content  thumbsUpCount  \
# 0      I have the same recurring tasks to do every da...             11
# ...

# %%
# Convert all text in the DataFrame to lowercase
df = df.apply(lambda x: x.astype(str).str.lower())

# %%
df
# Out:
#                                reviewId               userName userImage  \
# 0      0197c1185c6f4a7b894c970023d1a350                mar zur
# 1      94868fb5a21d4ef9ab8581b2ed3d0785           devin rivera
# 2      825da34ef65d4ef3991d02d5291820d6          heidi kinsley
# 3      a49c2875651a4c33b79c5813780d659e          daniel keller
# 4      9482c75e2e6346ab8c9447273dd6a829          a google user
# ...                                 ...                    ...       ...
# 16782  e9cebff882ad4191b196127a65e9036d  alexandra grafwallner
# 16783  ab74c21c35874393a53d4cb55f3e3c9b          ljubica pejic
# 16784  0062b15d6e4d4f0a9ea6ef9b9420d923         kamiyah dorsey
# 16785  85318bf27ca04d5e8cb2f0f18c813e4d         keturah pender
# 16786  8e2deadd1a6a481789dc4bd9a198332c    bhagwan singh virik
#
#                                                  content thumbsUpCount  \
# 0      i have the same recurring tasks to do every da...            11
# ...

# %%
# Define a regular expression pattern to match words containing numbers
pattern = r'\b\w*\d\w*\b'

# Remove words containing numbers from all columns in the DataFrame
df = df.replace(pattern, '', regex=True)

# %%
# Remove words containing numbers from the 'content' column
df['content'] = df['content'].replace(pattern, '', regex=True)

# %%
df
# Out:
#       reviewId               userName userImage  \
# 0                             mar zur
# 1                        devin rivera
# 2                       heidi kinsley
# 3                       daniel keller
# 4                       a google user
# ...        ...                    ...       ...
# 16782           alexandra grafwallner
# 16783                   ljubica pejic
# 16784                  kamiyah dorsey
# 16785                  keturah pender
# 16786             bhagwan singh virik
#
#                                                  content thumbsUpCount  \
# 0      i have the same recurring tasks to do every da...
# 1      instead of shopping around i downloaded anydo ...
# 2      why does every once in a while out of the blue...
# 3      terrible update this app used to be perfect fo...
# 4      this app is deceivingly terrible there are som...
# ...                                                  ...           ...
# ...

# %%
# Remove extra spaces from all columns in the DataFrame
df = df.replace(r'\s+', ' ', regex=True)

# %%
df
# Out:
#       reviewId               userName userImage  \
# 0                             mar zur
# 1                        devin rivera
# 2                       heidi kinsley
# 3                       daniel keller
# 4                       a google user
# ...        ...                    ...       ...
# 16782           alexandra grafwallner
# 16783                   ljubica pejic
# 16784                  kamiyah dorsey
# 16785                  keturah pender
# 16786             bhagwan singh virik
#
#                                                  content thumbsUpCount  \
# 0      i have the same recurring tasks to do every da...
# 1      instead of shopping around i downloaded anydo ...
# 2      why does every once in a while out of the blue...
# 3      terrible update this app used to be perfect fo...
# 4      this app is deceivingly terrible there are som...
# ...                                                  ...           ...
# ...

# %%
# Remove newline characters from all columns in the DataFrame
df = df.replace(r'\n', ' ', regex=True)

# %%
df
# Out:
#       reviewId               userName userImage  \
# 0                             mar zur
# 1                        devin rivera
# 2                       heidi kinsley
# 3                       daniel keller
# 4                       a google user
# ...        ...                    ...       ...
# 16782           alexandra grafwallner
# 16783                   ljubica pejic
# 16784                  kamiyah dorsey
# 16785                  keturah pender
# 16786             bhagwan singh virik
#
#                                                  content thumbsUpCount  \
# 0      i have the same recurring tasks to do every da...
# 1      instead of shopping around i downloaded anydo ...
# 2      why does every once in a while out of the blue...
# 3      terrible update this app used to be perfect fo...
# 4      this app is deceivingly terrible there are som...
# ...                                                  ...           ...
# ...

# %%
import nltk
from nltk.corpus import stopwords

# %%
import nltk
from nltk.corpus import stopwords

# Download NLTK stopwords if you haven't already
nltk.download('stopwords')

# Remove stop words from all columns in the DataFrame
stop_words = set(stopwords.words('english'))
df = df.apply(lambda x: x.apply(lambda y: ' '.join([word for word in str(y).split() if word.lower() not in stop_words])))

# Now, stop words are removed from the DataFrame
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sumit\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df
# Out:
#       reviewId               userName userImage  \
# 0                             mar zur
# 1                        devin rivera
# 2                       heidi kinsley
# 3                       daniel keller
# 4                         google user
# ...        ...                    ...       ...
# 16782           alexandra grafwallner
# 16783                   ljubica pejic
# 16784                  kamiyah dorsey
# 16785                  keturah pender
# 16786             bhagwan singh virik
#
#                                                  content thumbsUpCount  \
# 0      recurring tasks every day need todolist remind...
# 1      instead shopping around downloaded anydo widel...
# 2      every blue app asks update acct emails everyth...
# 3      terrible update app used perfect planning cert...
# 4      app deceivingly terrible really nice design fe...
# ...                                                  ...           ...
# ...
