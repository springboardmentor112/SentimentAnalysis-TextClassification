# %%
import pandas as pd

# %%
df=pd.read_csv('/content/reviews.csv')

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  0197c118-5c6f-4a7b-894c-970023d1a350        Mar Zur
# 1  94868fb5-a21d-4ef9-ab85-81b2ed3d0785   Devin Rivera
# 2  825da34e-f65d-4ef3-991d-02d5291820d6  Heidi Kinsley
# 3  a49c2875-651a-4c33-b79c-5813780d659e  Daniel Keller
# 4  9482c75e-2e63-46ab-8c94-47273dd6a829  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  thumbsUpCount  \
# 0  I have the same recurring tasks to do every da...             11
# 1  Instead of shopping around, I downloaded Any.d...              8
# 2  Why does every once in a while... out of the b...              6
# ...

# %% [markdown]
# 1) **LOWERCASE**

# %%
df['content']
# Out:
# 0        I have the same recurring tasks to do every da...
# 1        Instead of shopping around, I downloaded Any.d...
# 2        Why does every once in a while... out of the b...
# 3        Terrible Update! This app used to be perfect f...
# 4        This app is deceivingly terrible. There are so...
#                                ...
# 16782                                        Excellent app
# 16783    I love it. Easy to use. Make my life organize....
# 16784    I love how I could make plans and check the ap...
# 16785                             Exactly what I needed!!!
# 16786                                          Very good 👍
# Name: content, Length: 16787, dtype: object

# %%
df['content'].str.lower()
# Out:
# 0        i have the same recurring tasks to do every da...
# 1        instead of shopping around, i downloaded any.d...
# 2        why does every once in a while... out of the b...
# 3        terrible update! this app used to be perfect f...
# 4        this app is deceivingly terrible. there are so...
#                                ...
# 16782                                        excellent app
# 16783    i love it. easy to use. make my life organize....
# 16784    i love how i could make plans and check the ap...
# 16785                             exactly what i needed!!!
# 16786                                          very good 👍
# Name: content, Length: 16787, dtype: object

# %%
df['content'] = df['content'].str.lower()

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  0197c118-5c6f-4a7b-894c-970023d1a350        Mar Zur
# 1  94868fb5-a21d-4ef9-ab85-81b2ed3d0785   Devin Rivera
# 2  825da34e-f65d-4ef3-991d-02d5291820d6  Heidi Kinsley
# 3  a49c2875-651a-4c33-b79c-5813780d659e  Daniel Keller
# 4  9482c75e-2e63-46ab-8c94-47273dd6a829  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  thumbsUpCount  \
# 0  i have the same recurring tasks to do every da...             11
# 1  instead of shopping around, i downloaded any.d...              8
# 2  why does every once in a while... out of the b...              6
# ...

# %% [markdown]
# 2) **Romove link**

# %%
df['content']
# Out:
# 0        i have the same recurring tasks to do every da...
# 1        instead of shopping around, i downloaded any.d...
# 2        why does every once in a while... out of the b...
# 3        terrible update! this app used to be perfect f...
# 4        this app is deceivingly terrible. there are so...
#                                ...
# 16782                                        excellent app
# 16783    i love it. easy to use. make my life organize....
# 16784    i love how i could make plans and check the ap...
# 16785                             exactly what i needed!!!
# 16786                                          very good 👍
# Name: content, Length: 16787, dtype: object

# %%
import re
df['content'] = df['content'].apply(lambda x: re.split('https:\/\/.*|http:\/\/.*', str(x))[0])

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  0197c118-5c6f-4a7b-894c-970023d1a350        Mar Zur
# 1  94868fb5-a21d-4ef9-ab85-81b2ed3d0785   Devin Rivera
# 2  825da34e-f65d-4ef3-991d-02d5291820d6  Heidi Kinsley
# 3  a49c2875-651a-4c33-b79c-5813780d659e  Daniel Keller
# 4  9482c75e-2e63-46ab-8c94-47273dd6a829  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  thumbsUpCount  \
# 0  i have the same recurring tasks to do every da...             11
# 1  instead of shopping around, i downloaded any.d...              8
# 2  why does every once in a while... out of the b...              6
# ...

# %% [markdown]
# 3) **Remove next line**

# %%
df['content'].str.replace('\n', ' ').replace('\r', '')
# Out:
# 0        i have the same recurring tasks to do every da...
# 1        instead of shopping around, i downloaded any.d...
# 2        why does every once in a while... out of the b...
# 3        terrible update! this app used to be perfect f...
# 4        this app is deceivingly terrible. there are so...
#                                ...
# 16782                                        excellent app
# 16783    i love it. easy to use. make my life organize....
# 16784    i love how i could make plans and check the ap...
# 16785                             exactly what i needed!!!
# 16786                                          very good 👍
# Name: content, Length: 16787, dtype: object

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  0197c118-5c6f-4a7b-894c-970023d1a350        Mar Zur
# 1  94868fb5-a21d-4ef9-ab85-81b2ed3d0785   Devin Rivera
# 2  825da34e-f65d-4ef3-991d-02d5291820d6  Heidi Kinsley
# 3  a49c2875-651a-4c33-b79c-5813780d659e  Daniel Keller
# 4  9482c75e-2e63-46ab-8c94-47273dd6a829  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  thumbsUpCount  \
# 0  i have the same recurring tasks to do every da...             11
# 1  instead of shopping around, i downloaded any.d...              8
# 2  why does every once in a while... out of the b...              6
# ...

# %% [markdown]
# 4) **Romove Word continging Number**

# %%
def word_number(text):
  return ''.join(i for i in text if not i.isdigit())

# %%
df['content'].apply(word_number)
# Out:
# 0        i have the same recurring tasks to do every da...
# 1        instead of shopping around, i downloaded any.d...
# 2        why does every once in a while... out of the b...
# 3        terrible update! this app used to be perfect f...
# 4        this app is deceivingly terrible. there are so...
#                                ...
# 16782                                        excellent app
# 16783    i love it. easy to use. make my life organize....
# 16784    i love how i could make plans and check the ap...
# 16785                             exactly what i needed!!!
# 16786                                          very good 👍
# Name: content, Length: 16787, dtype: object

# %%
df['content'] = df['content'].apply(word_number)

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  0197c118-5c6f-4a7b-894c-970023d1a350        Mar Zur
# 1  94868fb5-a21d-4ef9-ab85-81b2ed3d0785   Devin Rivera
# 2  825da34e-f65d-4ef3-991d-02d5291820d6  Heidi Kinsley
# 3  a49c2875-651a-4c33-b79c-5813780d659e  Daniel Keller
# 4  9482c75e-2e63-46ab-8c94-47273dd6a829  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  thumbsUpCount  \
# 0  i have the same recurring tasks to do every da...             11
# 1  instead of shopping around, i downloaded any.d...              8
# 2  why does every once in a while... out of the b...              6
# ...

# %% [markdown]
# 5) **Romove Extra space**

# %%
df['content']
# Out:
# 0        i have the same recurring tasks to do every da...
# 1        instead of shopping around, i downloaded any.d...
# 2        why does every once in a while... out of the b...
# 3        terrible update! this app used to be perfect f...
# 4        this app is deceivingly terrible. there are so...
#                                ...
# 16782                                        excellent app
# 16783    i love it. easy to use. make my life organize....
# 16784    i love how i could make plans and check the ap...
# 16785                             exactly what i needed!!!
# 16786                                          very good 👍
# Name: content, Length: 16787, dtype: object

# %%
df['content'].str.replace("  ","")
# Out:
# 0        i have the same recurring tasks to do every da...
# 1        instead of shopping around, i downloaded any.d...
# 2        why does every once in a while... out of the b...
# 3        terrible update! this app used to be perfect f...
# 4        this app is deceivingly terrible. there are so...
#                                ...
# 16782                                        excellent app
# 16783    i love it. easy to use. make my life organize....
# 16784    i love how i could make plans and check the ap...
# 16785                             exactly what i needed!!!
# 16786                                          very good 👍
# Name: content, Length: 16787, dtype: object

# %%
df['content'] = df['content'].str.replace("  ","")

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  0197c118-5c6f-4a7b-894c-970023d1a350        Mar Zur
# 1  94868fb5-a21d-4ef9-ab85-81b2ed3d0785   Devin Rivera
# 2  825da34e-f65d-4ef3-991d-02d5291820d6  Heidi Kinsley
# 3  a49c2875-651a-4c33-b79c-5813780d659e  Daniel Keller
# 4  9482c75e-2e63-46ab-8c94-47273dd6a829  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  thumbsUpCount  \
# 0  i have the same recurring tasks to do every da...             11
# 1  instead of shopping around, i downloaded any.d...              8
# 2  why does every once in a while... out of the b...              6
# ...

# %% [markdown]
# 6)** Remove Special characters**

# %%
def special(text):
  return re.sub('[^A-Za-z0-9.]+', ' ',text)

# %%
df['content'].apply(special)
# Out:
# 0        i have the same recurring tasks to do every da...
# 1        instead of shopping around i downloaded any.do...
# 2        why does every once in a while... out of the b...
# 3        terrible update this app used to be perfect fo...
# 4        this app is deceivingly terrible. there are so...
#                                ...
# 16782                                        excellent app
# 16783    i love it. easy to use. make my life organize....
# 16784    i love how i could make plans and check the ap...
# 16785                               exactly what i needed
# 16786                                           very good
# Name: content, Length: 16787, dtype: object

# %%
df['content'] = df['content'].apply(special)

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  0197c118-5c6f-4a7b-894c-970023d1a350        Mar Zur
# 1  94868fb5-a21d-4ef9-ab85-81b2ed3d0785   Devin Rivera
# 2  825da34e-f65d-4ef3-991d-02d5291820d6  Heidi Kinsley
# 3  a49c2875-651a-4c33-b79c-5813780d659e  Daniel Keller
# 4  9482c75e-2e63-46ab-8c94-47273dd6a829  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  thumbsUpCount  \
# 0  i have the same recurring tasks to do every da...             11
# 1  instead of shopping around i downloaded any.do...              8
# 2  why does every once in a while... out of the b...              6
# ...

# %% [markdown]
# 7) Removal of Stop words

# %%
# !pip install nltk

# %%
from nltk.corpus import stopwords

# %%
def remove_stopwords(text):
  new_text = []

  for word in text.split():
    if word in stopwords.words('english'):
      new_text.append('')
    else:
      new_text.append(word)
  x= new_text[:]
  new_text.clear()
  return " ".join(x)

# %%
df['content']
# Out:
# 0        i have the same recurring tasks to do every da...
# 1        instead of shopping around i downloaded any.do...
# 2        why does every once in a while... out of the b...
# 3        terrible update this app used to be perfect fo...
# 4        this app is deceivingly terrible. there are so...
#                                ...
# 16782                                        excellent app
# 16783    i love it. easy to use. make my life organize....
# 16784    i love how i could make plans and check the ap...
# 16785                               exactly what i needed
# 16786                                           very good
# Name: content, Length: 16787, dtype: object

# %%
df['content'].apply(remove_stopwords)
# Out:
# 0            recurring tasks   every day.  need    list...
# 1        instead  shopping around  downloaded any.do   ...
# 2          every    while...    blue  app asks  update ...
# 3        terrible update  app used   perfect  planning ...
# 4         app  deceivingly terrible.    really nice des...
#                                ...
# 16782                                        excellent app
# 16783     love it. easy  use. make  life organize.  lov...
# 16784     love   could make plans  check  app almost ev...
# 16785                                     exactly   needed
# 16786                                                 good
# Name: content, Length: 16787, dtype: object

# %%
df['content'] = df['content'].apply(remove_stopwords)

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  0197c118-5c6f-4a7b-894c-970023d1a350        Mar Zur
# 1  94868fb5-a21d-4ef9-ab85-81b2ed3d0785   Devin Rivera
# 2  825da34e-f65d-4ef3-991d-02d5291820d6  Heidi Kinsley
# 3  a49c2875-651a-4c33-b79c-5813780d659e  Daniel Keller
# 4  9482c75e-2e63-46ab-8c94-47273dd6a829  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  thumbsUpCount  \
# 0      recurring tasks   every day.  need    list...             11
# 1  instead  shopping around  downloaded any.do   ...              8
# 2    every    while...    blue  app asks  update ...              6
# ...

# %% [markdown]
# 8) **Stemming**

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()
def stem_word(text):
  return " ".join([ps.stem(word) for word in text.split()])

# %%
df['content']
# Out:
# 0            recurring tasks   every day.  need    list...
# 1        instead  shopping around  downloaded any.do   ...
# 2          every    while...    blue  app asks  update ...
# 3        terrible update  app used   perfect  planning ...
# 4         app  deceivingly terrible.    really nice des...
#                                ...
# 16782                                        excellent app
# 16783     love it. easy  use. make  life organize.  lov...
# 16784     love   could make plans  check  app almost ev...
# 16785                                     exactly   needed
# 16786                                                 good
# Name: content, Length: 16787, dtype: object

# %%
df['content'].apply(stem_word)
# Out:
# 0        recur task everi day. need list remind buzz ti...
# 1        instead shop around download any.do wide use i...
# 2        everi while... blue app ask updat acct email e...
# 3        terribl updat app use perfect plan certain tas...
# 4        app deceivingli terrible. realli nice design f...
#                                ...
# 16782                                            excel app
# 16783    love it. easi use. make life organize. love wa...
# 16784    love could make plan check app almost everyday...
# 16785                                         exactli need
# 16786                                                 good
# Name: content, Length: 16787, dtype: object

# %%
df['content'] = df['content'].apply(stem_word)

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  0197c118-5c6f-4a7b-894c-970023d1a350        Mar Zur
# 1  94868fb5-a21d-4ef9-ab85-81b2ed3d0785   Devin Rivera
# 2  825da34e-f65d-4ef3-991d-02d5291820d6  Heidi Kinsley
# 3  a49c2875-651a-4c33-b79c-5813780d659e  Daniel Keller
# 4  9482c75e-2e63-46ab-8c94-47273dd6a829  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  thumbsUpCount  \
# 0  recur task everi day. need list remind buzz ti...             11
# 1  instead shop around download any.do wide use i...              8
# 2  everi while... blue app ask updat acct email e...              6
# ...

# %% [markdown]
# 8) **Lamatization**

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

stopword = stopwords.words('english')
wordnet_lemmatizer = WordNetLemmatizer()

# %%
def lamma(text):
  word_tokens = nltk.word_tokenize(text)
  lemmatized_word = [wordnet_lemmatizer.lemmatize(word) for word in word_tokens]
  return lemmatized_word

# %%
df['content']
# Out:
# 0        recur task everi day. need list remind buzz ti...
# 1        instead shop around download any.do wide use i...
# 2        everi while... blue app ask updat acct email e...
# 3        terribl updat app use perfect plan certain tas...
# 4        app deceivingli terrible. realli nice design f...
#                                ...
# 16782                                            excel app
# 16783    love it. easi use. make life organize. love wa...
# 16784    love could make plan check app almost everyday...
# 16785                                         exactli need
# 16786                                                 good
# Name: content, Length: 16787, dtype: object

# %%
df['content'].apply(lamma)
# Out:
# 0        [recur, task, everi, day, ., need, list, remin...
# 1        [instead, shop, around, download, any.do, wide...
# 2        [everi, while, ..., blue, app, ask, updat, acc...
# 3        [terribl, updat, app, use, perfect, plan, cert...
# 4        [app, deceivingli, terrible, ., realli, nice, ...
#                                ...
# 16782                                         [excel, app]
# 16783    [love, it, ., easi, use, ., make, life, organi...
# 16784    [love, could, make, plan, check, app, almost, ...
# 16785                                      [exactli, need]
# 16786                                               [good]
# Name: content, Length: 16787, dtype: object

# %%
df['content'] = df['content'].apply(lamma)

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  0197c118-5c6f-4a7b-894c-970023d1a350        Mar Zur
# 1  94868fb5-a21d-4ef9-ab85-81b2ed3d0785   Devin Rivera
# 2  825da34e-f65d-4ef3-991d-02d5291820d6  Heidi Kinsley
# 3  a49c2875-651a-4c33-b79c-5813780d659e  Daniel Keller
# 4  9482c75e-2e63-46ab-8c94-47273dd6a829  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  thumbsUpCount  \
# 0  [recur, task, everi, day, ., need, list, remin...             11
# 1  [instead, shop, around, download, any.do, wide...              8
# 2  [everi, while, ..., blue, app, ask, updat, acc...              6
# ...

# %%
df.to_csv('update')
