# %% [markdown]
# # Data Preprocessing Techniques on Reviews

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud,STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import re,string,unicodedata
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,f1_score
from sklearn.model_selection import train_test_split
from string import punctuation
from nltk import pos_tag
from nltk import pos_tag
from nltk.corpus import wordnet
import re
import warnings

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in d:\anaconda installed\lib\site-packages (1.9.3)
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy>=1.6.1 in c:\users\laksh\appdata\roaming\python\python311\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in c:\users\laksh\appdata\roaming\python\python311\site-packages (from wordcloud) (9.5.0)
# Requirement already satisfied: matplotlib in d:\anaconda installed\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda installed\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda installed\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda installed\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda installed\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\laksh\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\anaconda installed\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\laksh\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\laksh\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
df=pd.read_csv(r"D:\Sentiment_InfosysIntern\data_preprocessing\reviews.csv",encoding='latin-1')

# %%
df.head(10)
# Out:
#                                reviewId       userName  \
# 0  0197c118-5c6f-4a7b-894c-970023d1a350        Mar Zur
# 1  94868fb5-a21d-4ef9-ab85-81b2ed3d0785   Devin Rivera
# 2  825da34e-f65d-4ef3-991d-02d5291820d6  Heidi Kinsley
# 3  a49c2875-651a-4c33-b79c-5813780d659e  Daniel Keller
# 4  9482c75e-2e63-46ab-8c94-47273dd6a829  A Google user
# 5  6446c87d-e045-4325-b154-042cde863d74  A Google user
# 6  afe06e54-1014-49fa-80a6-f2b74880ef7c   rainrunner13
# 7  8256ea78-31ef-4eb4-abb0-1411d11a7d9e      Syd Stoll
# 8  775c3273-36cc-4787-a126-06ec46834507  A Google user
# 9  9f47e332-2c56-426c-8430-ce8ffde55706  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
# 5  https://play-lh.googleusercontent.com/EGemoI2N...
# 6  https://play-lh.googleusercontent.com/a-/ALV-U...
# 7  https://play-lh.googleusercontent.com/a/ACg8oc...
# 8  https://play-lh.googleusercontent.com/EGemoI2N...
# 9  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  thumbsUpCount  \
# 0  I have the same recurring tasks to do every da...             11
# 1  Instead of shopping around, I downloaded Any.d...              8
# 2  Why does every once in a while... out of the b...              6
# 3  Terrible Update! This app used to be perfect f...              5
# 4  This app is deceivingly terrible. There are so...             20
# 5  Smart Grocery List From Hell. While it might b...             19
# 6  Wunderlist was everything I needed and I had n...              6
# 7  I have had this app for almost a year. I was r...             84
# 8  Almost perfect but the developers choose to ig...              3
# 9  Very annoyed that I have to keep signing in an...             29
#
#   reviewCreatedVersion                at  \
# 0             4.16.6.2  22-07-2020 13:13
# 1                  NaN  08-12-2020 06:24
# 2             5.11.1.2  09-07-2021 13:51
# 3                  NaN  16-11-2020 01:50
# 4             4.14.0.4  31-01-2019 16:19
# 5             4.12.0.5  17-01-2019 00:09
# 6                  NaN  30-04-2020 06:46
# 7             5.15.2.1  07-11-2021 15:58
# 8                  NaN  07-07-2019 15:10
# 9            4.15.8.11  29-09-2019 16:03
#
#                                         replyContent         repliedAt  \
# 0  Our team will be happy to look into it for you...  23-07-2020 16:32
# 1  We are not aware of any issues with randomized...  10-12-2020 09:38
# 2  Sorry to hear that! It sounds like you might h...  11-07-2021 11:16
# 3  Please note that the tasks in your tasks view ...  17-11-2020 09:31
# 4  Hi Ryan, it sounds like you are describing our...  05-02-2019 11:52
# 5  Please note that you can turn off the smart li...  30-01-2019 15:18
# 6  Any.do is a task management app, which has no ...  03-05-2020 10:27
# 7  This could happen if a user pressed on an adve...  08-11-2021 14:36
# 8  Popups have been proven to increase productivi...  09-07-2019 11:09
# 9  Hi, that's odd, please send us a bug report in...  02-10-2019 19:51
#
#   appVersion      sortOrder      appId
# 0   4.16.6.2  most_relevant  com.anydo
# 1        NaN  most_relevant  com.anydo
# 2   5.11.1.2  most_relevant  com.anydo
# 3        NaN  most_relevant  com.anydo
# 4   4.14.0.4  most_relevant  com.anydo
# 5   4.12.0.5  most_relevant  com.anydo
# 6        NaN  most_relevant  com.anydo
# 7   5.15.2.1  most_relevant  com.anydo
# 8        NaN  most_relevant  com.anydo
# 9  4.15.8.11  most_relevant  com.anydo

# %%
df['content']=df['content'].str.lower()

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\laksh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# do we neeed to customize the stop words as per data??

from nltk.corpus import stopwords
stop_words = stopwords.words('english')
new_stopwords = ["would","shall","could","might"]
stop_words.extend(new_stopwords)
stop_words.remove("not")
stop_words=set(stop_words)
print(stop_words)
# Out:
# {'both', 'up', "weren't", "shouldn't", 'aren', 'until', 'do', 'from', "won't", 'how', 'm', 'here', 'an', 'why', 'over', 'off', 'now', 'further', 't', 'don', 'whom', 'me', 'few', 'didn', 'under', 'after', 'yourself', "you're", "she's", 'will', 'its', 'having', 'nor', 'very', "haven't", 'has', 'yours', 'a', "you've", 'because', 'more', 'and', 'only', "aren't", 'doesn', 'just', 'they', "hadn't", 'could', 'than', 'when', 'own', 'isn', 'them', 'been', 'against', 'once', 'those', 'shouldn', 'his', 'o', 'themselves', 'this', 'we', 'herself', 'some', "wasn't", 'weren', 'hadn', "you'll", 'itself', 'should', 'you', 'mustn', 'is', 'be', "mustn't", 'he', 'wouldn', 'wasn', 'himself', 'doing', 'there', 'd', 'by', 'in', 'on', 'with', 'needn', 're', "didn't", 'yourselves', 'mightn', 'or', 'to', 'that', 'all', 'being', "it's", 'what', 'for', 'y', 'down', 'same', 'at', "that'll", 'below', 'am', "don't", 'couldn', 'of', 'ma', 'above', 'theirs', 'into', 'hasn', 'won', 'ain', 'have', 'no', 'him', "wouldn't", 'where', 's', 'any', 'other', "needn't", 'are', 'the', "shan't", 'was', "should've", 'which', 'myself', 'so', 'each', 'most', 'shan', 'haven', 'as', 'it', 'about', 'might', 'our', 'were', 'shall', 'these', "doesn't", 'can', 'did', 'had', 'during', 'through', 'such', "isn't", "you'd", 've', 'my', 'ours', 'hers', 'their', 'her', 'before', 'she', "couldn't", 'too', 'but', 'between', "mightn't", 'if', 'again', 'while', 'your', 'would', 'i', 'then', 'does', 'll', 'ourselves', 'out', 'who', "hasn't"}

# %% [markdown]
# # Data cleaning and preprocessing pipeline

# %%
df = df.dropna(subset=['content'])  # removing the rows which has null values in content column

# %%
df.isna().sum()
# Out:
# reviewId                   0
# userName                   0
# userImage                  0
# content                    0
# thumbsUpCount              0
# reviewCreatedVersion    2357
# at                         0
# replyContent            7619
# repliedAt               7619
# appVersion              2357
# sortOrder                  0
# appId                      0
# dtype: int64

# %%
def create_slang_dictionary(filename):
    chart_words = {}
    with open(filename, 'r') as file:
        for line in file:
            # Remove trailing newline character
            line = line.strip()
            # Split the line on the equals sign (=)
            abbreviation, meaning = line.split('=')
            chart_words[abbreviation] = meaning

    return chart_words

# Example usage
filename = r"D:\Sentiment_InfosysIntern\data_preprocessing\slang.txt"  # Replace with your actual filename
chart_words = create_slang_dictionary(filename)
print(chart_words)
# Out:
# {'AFAIK': 'As Far As I Know', 'AFK': 'Away From Keyboard', 'ASAP': 'As Soon As Possible', 'ATK': 'At The Keyboard', 'ATM': 'At The Moment', 'A3': 'Anytime, Anywhere, Anyplace', 'BAK': 'Back At Keyboard', 'BBL': 'Be Back Later', 'BBS': 'Be Back Soon', 'BFN': 'Bye For Now', 'B4N': 'Bye For Now', 'BRB': 'Be Right Back', 'BRT': 'Be Right There', 'BTW': 'By The Way', 'B4': 'Before', 'CU': 'See You', 'CUL8R': 'See You Later', 'CYA': 'See You', 'FAQ': 'Frequently Asked Questions', 'FC': 'Fingers Crossed', 'FWIW': "For What It's Worth", 'FYI': 'For Your Information', 'GAL': 'Get A Life', 'GG': 'Good Game', 'GN': 'Good Night', 'GMTA': 'Great Minds Think Alike', 'GR8': 'Great', 'G9': 'Genius', 'IC': 'I See', 'ICQ': 'I Seek you', 'ILU': 'I Love You', 'IMHO': 'In My Honest/Humble Opinion', 'IMO': 'In My Opinion', 'IOW': 'In Other Words', 'IRL': 'In Real Life', 'KISS': 'Keep It Simple, Stupid', 'LDR': 'Long Distance Relationship', 'LMAO': 'Laugh', 'LOL': 'Laughing out loud', 'LTNS': 'Long Time No See', 'L8R': 'Later', 'MTE': 'My Thoughts Exactly', 'M8': 'Mate', 'NRN': 'No Reply Necessary', 'OIC': 'Oh I See', 'PITA': 'Pain', 'PRT': 'Party', 'PRW': 'Parents Are Watching', 'QPSA': 'Que Pasa', 'ROFL': 'Rolling On The Floor Laughing', 'ROFLOL': 'Rolling On The Floor Laughing Out Loud', 'ROTFLMAO': 'Rolling On The Floor Laughing', 'SK8': 'Skate', 'STATS': 'Your sex and age', 'ASL': 'Age, Sex, Location', 'THX': 'Thank You', 'TTFN': 'Ta-Ta For Now!', 'TTYL': 'Talk To You Later', 'U': 'You', 'U2': 'You Too', 'U4E': 'Yours For Ever', 'WB': 'Welcome Back', 'WTF': 'What The hell', 'WTG': 'Way To Go!', 'WUF': 'Where Are You From?', 'W8': 'Wait', '7K': 'Laugher', 'TFW': 'That feeling when', 'MFW': 'My face when', 'MRW': 'My reaction when', 'IFYP': 'I feel your pain', 'TNTL': 'Trying not to laugh', 'JK': 'Just kidding', 'IDC': 'I donâ€™t care', 'ILY': 'I love you', 'IMU': 'I miss you', 'ADIH': 'Another day in hell', 'ZZZ': 'Sleeping, bored, tired', 'WYWH': 'Wish you were here', 'TIME': 'Tears in my eyes', 'BAE': 'Before anyone else', 'FIMH': 'Forever in my heart', 'BSAAW': 'Big smile and a wink', 'BWL': 'Bursting with laughter', 'BFF': 'Best friends forever', 'CSL': 'laughing'}

# %%
  #---------------------------
    #Removal of special character
def remove_html_tags(text):
    pattern=re.compile('<.*?>')
    return pattern.sub(r'',text)
    
def remove_special_character(content): # removes punctuations
    return re.sub('\W+',' ', content )#re.sub('\[[^&@#!]]*\]', '', content)#return re.sub('\[[^&@#!]]*\]','',content)

#Removal of URLs
def remove_url(content): 
    return re.sub(r'http\S+', '', content)

# remove stop words from text
def remove_stopwords(content):
    clean_data = []
    for i in content.split():
        if i.strip().lower() not in stop_words and i.strip().lower().isalpha():
            clean_data.append(i.strip().lower())
    return " ".join(clean_data)

# %%
def contraction_expansion(content):
    content = re.sub(r"won\'t", "would not", content)
    content = re.sub(r"can\'t", "can not", content)
    content = re.sub(r"don\'t", "do not", content)
    content = re.sub(r"shouldn\'t", "should not", content)
    content = re.sub(r"needn\'t", "need not", content)
    content = re.sub(r"hasn\'t", "has not", content)
    content = re.sub(r"haven\'t", "have not", content)
    content = re.sub(r"weren\'t", "were not", content)
    content = re.sub(r"mightn\'t", "might not", content)
    content = re.sub(r"didn\'t", "did not", content)
    content = re.sub(r"n\'t", " not", content)
    return content

# %% [markdown]
# # Data preprocessing

# %%
#Data preprocessing
def data_cleaning(content):
    if not pd.isna(content):  # Check for missing values (NaN) Issue solved as the null values as passed as float
        content = remove_html_tags(content)
        content = remove_url(content)
        content = remove_special_character(content)
        content = contraction_expansion(content)
        content = remove_stopwords(content)
    return content

# %% [markdown]
# # Data cleaning

# %%
df['content']=df['content'].apply(data_cleaning)

# %%
print(df['content'][10])
# Out:
# longer usable awful used free app years grocery lists simply laid easy use years created lists easily check uncheck reminders needed store idk happened last months app become useless exhaustive waste time completely erases items typed checked saved lists leaving waste time retype things uninstalled reinstalled nothing works

# %% [markdown]
# <Lemmatiation as needed to get the precise words meaning for obtaining the core details of app faults clearly>

# %% [markdown]
# !Lemmatization as needed to get the exact meaning of the customer query to address the app's fault

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
df['content'] = df['content'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# %%
df['content']
# Out:
# 0        recurring task every day need list reminder bu...
# 1        instead shopping around downloaded widely used...
# 2        every blue app asks update acct email everythi...
# 3        terrible update app used perfect planning cert...
# 4        app deceivingly terrible really nice design fe...
#                                ...
# 16782                                        excellent app
# 16783    love easy use make life organize love way put ...
# 16784        love make plan check app almost everyday love
# 16785                                       exactly needed
# 16786                                               good ð
# Name: content, Length: 16786, dtype: object

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\laksh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Data Overview

# %%
df['content'].describe()
# Out:
# count     16786
# unique    13118
# top        good
# freq        131
# Name: content, dtype: object

# %%
print('Unique reviews:%s'% df.content.nunique())
print('Unique reply count:%s'% df.replyContent.nunique()) # just to curious to see
# Out:
# Unique reviews:13118
# Unique reply count:6412

# %% [markdown]
# # EDA Exploratory Data Analysis

# %%
wordcloud = WordCloud(width=800, height=600, background_color="white")
# Generate the wordcloud from the preprocessed content
wordcloud.generate(" ".join(content))
# Display the wordcloud
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.title("Wordcloud of App Review Content")
plt.show()
